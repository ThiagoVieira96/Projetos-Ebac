# %% [markdown]
# # Livro para consulta:
# - https://jakevdp.github.io/PythonDataScienceHandbook/03.08-aggregation-and-grouping.html
# - https://jakevdp.github.io/PythonDataScienceHandbook/03.09-pivot-tables.html

# %% [markdown]
# # 1. Importando bibliotecas <a name="import"></a>
#
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # 2. Carregando o dataframe SINASC <a name="read"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
sinasc_raw = pd.read_csv('SINASC_RO_2019.csv')
sinasc_raw.head()
# Out:
#    ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 0       1  2679477.0      110001        1        19        5.0
# 1       1  2679477.0      110001        1        29        2.0
# 2       1  2679477.0      110001        1        37        9.0
# 3       1  2516500.0      110001        1        30        5.0
# 4       1  2516500.0      110001        1        30        2.0
#
#             ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# 0      8 a 11 anos         NaN         0.0         0.0  ...           5
# 1      8 a 11 anos    999992.0         1.0         0.0  ...           5
# 2      8 a 11 anos    513205.0         2.0         0.0  ...           5
# 3  12 anos ou mais    231205.0         0.0         0.0  ...           4
# 4      8 a 11 anos    999992.0         1.0         0.0  ...           5
#
#   CONTADOR munResStatus munResTipo               munResNome  munResUf  \
# 0        1        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# ...

# %% [markdown]
# # Tarefa 1

# %% [markdown]
# ### 1. Idade media das mães e dos pais por município (coluna munResNome)

# %%
sinasc_raw.groupby('munResNome')['IDADEMAE'].mean()
# Out:
# munResNome
# Alta Floresta D'Oeste        25.991826
# Alto Alegre dos Parecis      24.844156
# Alto Paraíso                 24.960177
# Alvorada D'Oeste             25.770732
# Ariquemes                    25.607866
# Buritis                      25.559177
# Cabixi                       26.037500
# Cacaulândia                  25.546667
# Cacoal                       26.890102
# Campo Novo de Rondônia       24.825301
# Candeias do Jamari           25.243323
# Castanheiras                 27.281250
# Cerejeiras                   27.240506
# Chupinguaia                  25.333333
# Colorado do Oeste            27.602804
# Corumbiara                   24.716535
# Costa Marques                24.412017
# Cujubim                      24.482927
# Espigão D'Oeste              26.093333
# Governador Jorge Teixeira    24.401786
# Guajará-Mirim                25.462228
# Itapuã do Oeste              26.064220
# Jaru                         25.982974
# Ji-Paraná                    26.361137
# ...

# %% [markdown]
# ### 2. Peso médio dos bebes por sexo que nasceram no dia do seu aniversário por faixas de escolaridade mae
# Ex: Você, aluna(o), nasceu no dia 10/01, então você precisa filtrar o conjunto de dados nessa data e calcular o peso médio dos bebês de cada sexo por faixa de escolaridade da mãe.

# %%
sinasc_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27028 entries, 0 to 27027
# Data columns (total 69 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ORIGEM        27028 non-null  int64
#  1   CODESTAB      26913 non-null  float64
#  2   CODMUNNASC    27028 non-null  int64
#  3   LOCNASC       27028 non-null  int64
#  4   IDADEMAE      27028 non-null  int64
#  5   ESTCIVMAE     26711 non-null  float64
#  6   ESCMAE        26716 non-null  object
#  7   CODOCUPMAE    24121 non-null  float64
#  8   QTDFILVIVO    25455 non-null  float64
#  9   QTDFILMORT    24930 non-null  float64
#  10  CODMUNRES     27028 non-null  int64
#  11  GESTACAO      25796 non-null  object
#  12  GRAVIDEZ      26949 non-null  object
#  13  PARTO         26979 non-null  object
#  14  CONSULTAS     27028 non-null  int64
#  15  DTNASC        27028 non-null  object
#  16  HORANASC      27007 non-null  float64
#  17  SEXO          27024 non-null  object
# ...

# %%
sinasc_raw.columns
# Out:
# Index(['ORIGEM', 'CODESTAB', 'CODMUNNASC', 'LOCNASC', 'IDADEMAE', 'ESTCIVMAE',
#        'ESCMAE', 'CODOCUPMAE', 'QTDFILVIVO', 'QTDFILMORT', 'CODMUNRES',
#        'GESTACAO', 'GRAVIDEZ', 'PARTO', 'CONSULTAS', 'DTNASC', 'HORANASC',
#        'SEXO', 'APGAR1', 'APGAR5', 'RACACOR', 'PESO', 'IDANOMAL', 'DTCADASTRO',
#        'CODANOMAL', 'NUMEROLOTE', 'VERSAOSIST', 'DTRECEBIM', 'DIFDATA',
#        'DTRECORIGA', 'NATURALMAE', 'CODMUNNATU', 'CODUFNATU', 'ESCMAE2010',
#        'SERIESCMAE', 'DTNASCMAE', 'RACACORMAE', 'QTDGESTANT', 'QTDPARTNOR',
#        'QTDPARTCES', 'IDADEPAI', 'DTULTMENST', 'SEMAGESTAC', 'TPMETESTIM',
#        'CONSPRENAT', 'MESPRENAT', 'TPAPRESENT', 'STTRABPART', 'STCESPARTO',
#        'TPNASCASSI', 'TPFUNCRESP', 'TPDOCRESP', 'DTDECLARAC', 'ESCMAEAGR1',
#        'STDNEPIDEM', 'STDNNOVA', 'CODPAISRES', 'TPROBSON', 'PARIDADE',
#        'KOTELCHUCK', 'CONTADOR', 'munResStatus', 'munResTipo', 'munResNome',
# ...

# %%
#Como a coluna 'DTNASC' é do tipo 'object', iremos primeiramente converte-la em datetime.
sinasc_raw['DTNASC'] = pd.to_datetime(sinasc_raw['DTNASC'])

# %%
sinasc_raw.info()
#Agora, vemos que a coluna está no formato desejado.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27028 entries, 0 to 27027
# Data columns (total 69 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ORIGEM        27028 non-null  int64
#  1   CODESTAB      26913 non-null  float64
#  2   CODMUNNASC    27028 non-null  int64
#  3   LOCNASC       27028 non-null  int64
#  4   IDADEMAE      27028 non-null  int64
#  5   ESTCIVMAE     26711 non-null  float64
#  6   ESCMAE        26716 non-null  object
#  7   CODOCUPMAE    24121 non-null  float64
#  8   QTDFILVIVO    25455 non-null  float64
#  9   QTDFILMORT    24930 non-null  float64
#  10  CODMUNRES     27028 non-null  int64
#  11  GESTACAO      25796 non-null  object
#  12  GRAVIDEZ      26949 non-null  object
#  13  PARTO         26979 non-null  object
#  14  CONSULTAS     27028 non-null  int64
#  15  DTNASC        27028 non-null  datetime64[ns]
#  16  HORANASC      27007 non-null  float64
# ...

# %%
#Agora, iremos criar um novo dataframe contendo apenas as linhas correspondentes ao meu aniversário (22/01)
sinasc_aniversario = sinasc_raw[sinasc_raw['DTNASC'].dt.day == 22][sinasc_raw['DTNASC'].dt.month == 1]
sinasc_aniversario.shape
# Out:
# C:\Users\samsun\AppData\Local\Temp\ipykernel_8628\2553433505.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sinasc_aniversario = sinasc_raw[sinasc_raw['DTNASC'].dt.day == 22][sinasc_raw['DTNASC'].dt.month == 1]
# (58, 69)

# %%
sinasc_aniversario.groupby(['PESO', 'SEXO'])['PESO'].mean().unstack()
# Out:
# SEXO  Feminino  Masculino
# PESO
# 1165    1165.0        NaN
# 1350    1350.0        NaN
# 1685       NaN     1685.0
# 1800    1800.0        NaN
# 2140       NaN     2140.0
# 2440       NaN     2440.0
# 2530       NaN     2530.0
# 2675    2675.0        NaN
# 2755    2755.0        NaN
# 2780    2780.0        NaN
# 2785       NaN     2785.0
# 2820    2820.0        NaN
# 2905    2905.0        NaN
# 2925       NaN     2925.0
# 2955    2955.0        NaN
# 2990       NaN     2990.0
# 3025    3025.0        NaN
# 3035       NaN     3035.0
# 3150    3150.0        NaN
# 3210       NaN     3210.0
# 3215    3215.0        NaN
# 3225       NaN     3225.0
# 3270    3270.0        NaN
# 3280       NaN     3280.0
# 3330    3330.0        NaN
# 3335    3335.0        NaN
# 3340       NaN     3340.0
# 3395       NaN     3395.0
# 3410    3410.0     3410.0
# 3415       NaN     3415.0
# 3425       NaN     3425.0
# 3455    3455.0        NaN
# 3475       NaN     3475.0
# 3480    3480.0        NaN
# ...

# %% [markdown]
# ### 3. Qual o municipio que nasceu menos bebe em 2019?
#     - qual a idade media, maxima, minima das maes nesse municipio?
#     - qual a idade media, maxima, minima dos pais nesse municipio?

# %%
sinasc_2019 = sinasc_raw[sinasc_raw['DTNASC'].dt.year == 2019]
sinasc_2019_mun = sinasc_2019['munResNome'].value_counts().nsmallest(5).index
sinasc_menos_nascimentos = sinasc_raw[sinasc_raw['munResNome'].isin(sinasc_2019_mun)]
sinasc_menos_nascimentos.groupby('munResNome').agg({'IDADEMAE': ['mean','min','max'], 'IDADEPAI':['mean','min','max']})
# Out:
#                           IDADEMAE           IDADEPAI
#                               mean min max       mean   min   max
# munResNome
# Castanheiras             27.281250  17  39  30.392857  17.0  43.0
# Município ignorado - RO  24.000000  24  24  22.000000  22.0  22.0
# Parecis                  26.454545  16  41  32.473684  18.0  61.0
# Pimenteiras do Oeste     25.075000  14  40  35.600000  25.0  45.0
# Primavera de Rondônia    27.023256  16  39  31.888889  21.0  44.0

# %% [markdown]
# ### 4. Qual o municipio que nasceu mais bebe no mês de março?
#     - qual a quantidade de filhos vivos media, maxima, minima nesse municipio?
#     - qual a idade media, maxima, minima dos pais nesse municipio?

# %%
sinasc_marco = sinasc_raw[sinasc_raw['DTNASC'].dt.month==2]
sinasc_marco_mun = sinasc_marco['munResNome'].value_counts().nlargest(5).index
sinasc_mais_nascimentos = sinasc_raw[sinasc_raw['munResNome'].isin(sinasc_marco_mun)]
sinasc_mais_nascimentos.groupby('munResNome').agg({'IDADEMAE': ['mean','min','max'], 'IDADEPAI':['mean','min','max']})
# Out:
#               IDADEMAE           IDADEPAI
#                   mean min max       mean   min   max
# munResNome
# Ariquemes    25.607866  13  44  32.466667  20.0  51.0
# Cacoal       26.890102  14  47  30.931854  17.0  66.0
# Ji-Paraná    26.361137  12  44  31.132239  15.0  63.0
# Porto Velho  26.312670  12  47  32.352679  16.0  65.0
# Vilhena      26.433962  14  46  34.152941  18.0  60.0

# %% [markdown]
# ### Analise as respostas encontradas, tire algum insight delas, conte pra gente algo encontrado nos dados. Algo que você julgue relevante e novo pra você.

# %% [markdown]
# Agora, análisando as tabelas acima, pode-se observar os seguintes insights:
#     - Em quase todas as cidades, a idade média da mãe é menor que a do pai.
#     - A cidade de Pimenteiras do Oeste foi a cidade com a maior diferença entre a idade média da mãe e do pai, sendo essa diferença de 10 anos.
#     - A diferença entre a idade mínima e máxima é sempre maior no pai do que na mãe, juntamente com a idade máxima.
#     - A idade média dos pais e mães dos municípios com a maior e menor quantidade de nascimentos não muda significantemente, isso pravavelmente se dá ao fato de que foram escolhidos intervalos diferentes (o ano de 2019 e todos os meses de março).

# %% [markdown]
# Exemplo:
# - Ah, descobri que a idade mediana das mulheres que deram a luz no ano de 2019 dos municipios x é maior que y.

# %%
sinasc_raw.dtypes
# Out:
# ORIGEM          int64
# CODESTAB      float64
# CODMUNNASC      int64
# LOCNASC         int64
# IDADEMAE        int64
#                ...
# munResUf       object
# munResLat     float64
# munResLon     float64
# munResAlt     float64
# munResArea    float64
# Length: 69, dtype: object

# %%
sinasc_raw.select_dtypes(exclude=['int64','float64'])
# Out:
#                 ESCMAE         GESTACAO GRAVIDEZ    PARTO      DTNASC  \
# 0          8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-02-19
# 1          8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-02-21
# 2          8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-02-25
# 3      12 anos ou mais  37 a 41 semanas    Única  Cesáreo  2019-03-20
# 4          8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-03-23
# ...                ...              ...      ...      ...         ...
# 27023  12 anos ou mais  32 a 36 semanas    Única  Cesáreo  2019-12-13
# 27024      8 a 11 anos  37 a 41 semanas    Única  Vaginal  2019-10-04
# 27025      8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-08-02
# 27026      8 a 11 anos  32 a 36 semanas    Única  Vaginal  2019-12-23
# 27027      8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-12-27
#
#             SEXO RACACOR  DTCADASTRO CODANOMAL VERSAOSIST   DTRECEBIM  \
# ...

# %%
sinasc_raw.columns
# Out:
# Index(['ORIGEM', 'CODESTAB', 'CODMUNNASC', 'LOCNASC', 'IDADEMAE', 'ESTCIVMAE',
#        'ESCMAE', 'CODOCUPMAE', 'QTDFILVIVO', 'QTDFILMORT', 'CODMUNRES',
#        'GESTACAO', 'GRAVIDEZ', 'PARTO', 'CONSULTAS', 'DTNASC', 'HORANASC',
#        'SEXO', 'APGAR1', 'APGAR5', 'RACACOR', 'PESO', 'IDANOMAL', 'DTCADASTRO',
#        'CODANOMAL', 'NUMEROLOTE', 'VERSAOSIST', 'DTRECEBIM', 'DIFDATA',
#        'DTRECORIGA', 'NATURALMAE', 'CODMUNNATU', 'CODUFNATU', 'ESCMAE2010',
#        'SERIESCMAE', 'DTNASCMAE', 'RACACORMAE', 'QTDGESTANT', 'QTDPARTNOR',
#        'QTDPARTCES', 'IDADEPAI', 'DTULTMENST', 'SEMAGESTAC', 'TPMETESTIM',
#        'CONSPRENAT', 'MESPRENAT', 'TPAPRESENT', 'STTRABPART', 'STCESPARTO',
#        'TPNASCASSI', 'TPFUNCRESP', 'TPDOCRESP', 'DTDECLARAC', 'ESCMAEAGR1',
#        'STDNEPIDEM', 'STDNNOVA', 'CODPAISRES', 'TPROBSON', 'PARIDADE',
#        'KOTELCHUCK', 'CONTADOR', 'munResStatus', 'munResTipo', 'munResNome',
# ...
